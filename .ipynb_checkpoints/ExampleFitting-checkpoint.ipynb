# %%
from calibrationnet.db import get_session
from sqlalchemy import select
from calibrationnet.models import RunPixel
from calibrationnet.models import TrapFilterOutput
import numpy as np
import matplotlib.pyplot as plt
import fit_functions as f
from lmfit import Parameters
import pylab as py
from importlib import reload

# %%
with get_session() as session:
    runpixel = session.execute(select(RunPixel).where(RunPixel.run_number==8622,RunPixel.pixel_number==60)).scalars().all()
    runpixel_id = runpixel[0].id
    raw_energy = session.execute(select(TrapFilterOutput.energies).where(TrapFilterOutput.run_pixel_id==runpixel_id)).scalars().all()

# %%
histogram = np.histogram(raw_energy[0],bins = np.arange(0,4500))

# %%
nrows,ncols=8,4
fig = py.figure(figsize=(8*ncols,6*nrows))

ax1=py.subplot(nrows,ncols,1)
ax2=py.subplot(nrows,ncols,2)
ax3=py.subplot(nrows,ncols,3)

ax1.stairs(histogram[0],histogram[1])
ax1.set_xlim(2500,3500)
ax1.set_ylim(0,1500)
ax1.set_title("3 high energy peaks")


ax2.stairs(histogram[0],histogram[1])
ax2.set_xlim(1200,1800)
ax2.set_ylim(0,700)
ax2.set_title("3 middle energy peaks")

ax3.stairs(histogram[0],histogram[1])
ax3.set_xlim(20,200)
ax3.set_ylim(0,300)
ax3.set_title("2 low energy peaks (we only fitting 2)")

plt.show()

# %% [markdown]
# # High energy Peak fit (two steps, one for highest intesity peak, second for two lower intensity peaks close together)

# %%
data = raw_energy[0]
lower_bound = 2700
upper_bound = 3000
peak_finder_parameters = (10,None,20,35,10,None,0.5,None)
number_peaks = 1
initial_peak_width_guess = {'sig1':5,'sig2':5,'sig3':5}

nrows,ncols=8,4
fig = py.figure(figsize=(8*ncols,6*nrows))
ax=py.subplot(nrows,ncols,1)

r = f.get_fit(data,lower_bound, upper_bound,peak_finder_parameters,number_peaks,initial_peak_width_guess,plot=True,axis=ax)

r.params['sig1']
r.params['sig1'].stderr
# Out:
# 0.16496883295434628

# %%
lower_bound = 3000
upper_bound = 3200
peak_finder_parameters = (10,None,20,35,10,None,0.5,None)
number_peaks = 2
initial_peak_width_guess = {'sig1':5,'sig2':5,'sig3':5}

nrows,ncols=8,4
fig = py.figure(figsize=(8*ncols,6*nrows))
ax=py.subplot(nrows,ncols,1)

r = f.get_fit(data,lower_bound, upper_bound,peak_finder_parameters,number_peaks,initial_peak_width_guess,plot=True,axis=ax)

# %%
find_peaks(x, height=None, threshold=None, distance=None, prominence=None, width=None, wlen=None, rel_height=0.5, plateau_size=None)

# %%
lower_bound = 1200
upper_bound = 1450
peak_finder_parameters = (10,None,20,35,5,None,0.5,None)
number_peaks = 1
initial_peak_width_guess = {'sig1':5,'sig2':5,'sig3':5}

nrows,ncols=8,4
fig = py.figure(figsize=(8*ncols,6*nrows))
ax=py.subplot(nrows,ncols,1)

r = f.get_fit(data,lower_bound, upper_bound,peak_finder_parameters,number_peaks,initial_peak_width_guess,plot=True,axis=ax)

r.params['sig1']
r.params['sig1'].stderr
# Out:
# 0.4056915723193872

# %%
lower_bound = 1500
upper_bound = 1750
peak_finder_parameters = (5,None,20,15,1,None,0.5,None)
number_peaks = 2
initial_peak_width_guess = {'sig1':3,'sig2':3,'sig3':5}

nrows,ncols=8,4
fig = py.figure(figsize=(8*ncols,6*nrows))
ax=py.subplot(nrows,ncols,1)

r = f.get_fit(data,lower_bound, upper_bound,peak_finder_parameters,number_peaks,initial_peak_width_guess,plot=True,axis=ax)

# %%
lower_bound = 20
upper_bound = 180
peak_finder_parameters = (5,None,20,15,1,None,0.5,None)
number_peaks = 2
initial_peak_width_guess = {'sig1':3,'sig2':3,'sig3':5}

nrows,ncols=8,4
fig = py.figure(figsize=(8*ncols,6*nrows))
ax=py.subplot(nrows,ncols,1)

r = f.get_fit(data,lower_bound, upper_bound,peak_finder_parameters,number_peaks,initial_peak_width_guess,plot=True,axis=ax)

# %%
r
# Out:
# <h2>Fit Result</h2> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>416</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>160</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>13</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 289.334288</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.96826047</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 120.785426</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 160.762685</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>num_peaks</td><td style='text-align:left'> 2.00000000</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>2.0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>False</td></tr><tr><td style='text-align:left'>slope</td><td style='text-align:left'> 0.12096994</td><td style='text-align:left'> 0.17499597</td><td style='text-align:left'>(144.66%)</td><td style='text-align:left'>-0.001</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>intercept</td><td style='text-align:left'> 0.44619343</td><td style='text-align:left'> 27.8726892</td><td style='text-align:left'>(6246.77%)</td><td style='text-align:left'>0.0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>beta</td><td style='text-align:left'> 72.4818642</td><td style='text-align:left'> 100.148046</td><td style='text-align:left'>(138.17%)</td><td style='text-align:left'>10.0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>amp1</td><td style='text-align:left'> 134.532075</td><td style='text-align:left'> 193.652464</td><td style='text-align:left'>(143.95%)</td><td style='text-align:left'>187.0</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>cen1</td><td style='text-align:left'> 79.4105859</td><td style='text-align:left'> 2.34175241</td><td style='text-align:left'>(2.95%)</td><td style='text-align:left'>75.0</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>sig1</td><td style='text-align:left'> 8.34245697</td><td style='text-align:left'> 1.59756163</td><td style='text-align:left'>(19.15%)</td><td style='text-align:left'>3.0</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>n1</td><td style='text-align:left'> 0.39939351</td><td style='text-align:left'> 1.15836553</td><td style='text-align:left'>(290.03%)</td><td style='text-align:left'>0.6</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 1.00000000</td><td style='text-align:right'>True</td ...
