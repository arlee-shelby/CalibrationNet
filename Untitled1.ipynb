# %%
import matplotlib.pyplot as plt
import calibrationnet.queries as q
import time
import pylab as py
from importlib import reload
import numpy as np

# %%
q.calibration_summary([9469], "nabpy-standard", "upper")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/NabEnv_db/lib/python3.11/site-packages/sqlalchemy/engine/base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File ~/NabEnv_db/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File ~/NabEnv_db/lib/python3.11/site-packages/sqlalchemy/pool/base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
# ...

# %%
fall = list(range(8622, 8866))
sets = {
    "Fall 2025 UDET": calibration_summary(fall, "nabpy-standard", "upper"),
    "Fall 2025 LDET": calibration_summary(fall, "short-trap-Fall2025", "lower"),
    "9469 UDET":      calibration_summary([9469], "nabpy-standard", "upper"),
    "9469 LDET":      calibration_summary([9469], "nabpy-standard", "lower"),
}
