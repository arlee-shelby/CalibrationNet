# %%
import h5py
import sys

sys.path.append('/Users/arleeshelby/ManitobaWork_1374/pyNab/src')
import nabPy as Nab

# %%
run = h5py.File("Run8622_0.h5")
pixel_map = run['Parameters/BoardChannelToPixelMap'][()]

# %%
pixel_map
# Out:
# array([[   0,   51],
#        [   1,   63],
#        [   2,   75],
#        [   3,   50],
#        [   4,   62],
#        [   5,   64],
#        [   6,   40],
#        [   7,   58],
#        [   8,   66],
#        [   9,   53],
#        [  10,   41],
#        [  11,   65],
#        [  12,   76],
#        [  13,   89],
#        [  14,   78],
#        [  15,   88],
#        [  16,   87],
#        [  17,   77],
#        [  18,   30],
#        [  19,   39],
#        [  20,   28],
#        [  21,   20],
#        [  22,   29],
#        [  23,   38],
#        [  24,   58],
#        [  25,   42],
#        [  26,   32],
#        [  27,   67],
#        [  28,   43],
#        [  29,   31],
#        [  30,   80],
#        [  31,   90],
#        [  32,  100],
#        [  33,   91],
#        [  34,   79],
#        [  35,  101],
#        [  36,  108],
#        [  37,   98],
#        [  38,  107],
#        [  39,   99],
#        [  40,  106],
#        [  41,   96],
#        [  42,   85],
# ...

# %%
runNumber = 8622
run = Nab.DataRun("Run8622_0.h5", runNumber, ignoreEventFile = True)
hits = run.plotHitLocations(sourceFile='singles',det='low')
Nab.nplt.plotOneDetector(hits,size = 1, forceMax = 200000)
